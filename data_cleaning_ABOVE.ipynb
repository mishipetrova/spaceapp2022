# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import Image

# %%
def bins_analysis(df, target_str, init_range, end_range, step_range):

    bins=list(np.arange(init_range,end_range,step_range))
    bins_df=list(np.arange(init_range-1,end_range,step_range))
    
    plt.hist(df[target_str], bins=bins, edgecolor="k")
    plt.xticks(bins)
    plt.xlabel(target_str)
    plt.ylabel("Count")
    
    df_bins_count=df.groupby(pd.cut(df[target_str], bins_df)).count()
    df_bins_count['pctg']=df_bins_count[target_str].div(df_bins_count[target_str].sum())
    df_bins_count=df_bins_count[[target_str, 'pctg']]
    
    return df_bins_count

# %%
#Calculate counts and each % of total

def ValueCountsPctgs(df, col):
    '''
    df: pandas dataframe
    col : column of interest(preferably with categorical values)
    
    '''
    counts=df[col].value_counts()
    pctgs=df[col].value_counts(normalize=True)

    table_counts_pctgs=pd.concat([counts,pctgs], axis=1, keys=('count','pctg')).reset_index().rename(columns={'index':col}) 
    
    return  table_counts_pctgs

# %% [markdown]
# # Data extraction

# %%
#read_csvs
data_burned=pd.read_csv('ABoVE\data\AK_CA_Burned_Plot_Data_1983_2016.csv')
data_soil=pd.read_csv('ABoVE\data\AK_CA_Soil_Profile_Synthesis.csv')

# %%
print("data_burned")
print(data_burned.shape)
print(data_burned.columns)
print('')
print('')
print("data_soil")
print(data_soil.shape)
print(data_soil.columns)
# Out:
# data_burned
# (1172, 49)
# Index(['project_id', 'project_name', 'treatment', 'site', 'burn_name',
#        'burn_year', 'ecoregion_name_l2', 'latitude', 'longitude',
#        'accuracy_horizontal', 'elevation', 'accuracy_vertical', 'slope',
#        'aspect', 'moisture', 'stand_density', 'stand_basal_area',
#        'prop_black_spruce', 'stand_age', 'stand_origin', 'ag_biomass_prefire',
#        'ag_c_prefire', 'ag_biomass_combusted', 'ag_c_combusted', 'prefire_sol',
#        'mean_residual_org_layer_depth', 'burn_depth', 'prop_sol_combusted',
#        'residual_sol_c', 'bg_c_prefire', 'bg_c_combusted',
#        'prop_sol_c_combusted', 'total_c_pool_prefire', 'prop_prefire_bg_c',
#        'total_c_combusted', 'prop_total_bg_c_combusted',
#        'prop_total_prefire_c_combusted', 'dob', 'precipitation', 'temperature',
#        'relative_humidity', 'wind_speed', 'drought_code',
#        'drought_moisture_code', 'fine_fuel_moisture_code',
#        'initial_spread_index', 'buildup_index', 'fire_weather_index',
#        'daily_severity_rank'],
#       dtype='object')
#
#
# data_soil
# (4538, 23)
# Index(['site', 'project_name', 'id', 'project_id', 'plot', 'latitude',
#        'longitude', 'treatment', 'profile', 'min_org', 'horizon', 'raw_depth',
#        'adjusted_depth', 'sample_depth', 'fine_coarse', 'fine_bulk_density',
#        'coarse_bulk_density', 'total_bulk_density', 'fine_carbon',
#        'fine_nitrogen', 'ph', 'dry_matter', 'carbon'],
#       dtype='object')

# %% [markdown]
# # EDA (burned)

# %%
ValueCountsPctgs(data_burned, 'treatment')
# Out:
#   treatment  count      pctg
# 0      burn   1012  0.863481
# 1   Control    160  0.136519

# %%
#Name of fire site
ValueCountsPctgs(data_burned, 'burn_name')[:10]
# Out:
#           burn_name  count      pctg
# 0              ZF20    110  0.100182
# 1               SS3     58  0.052823
# 2              ZF46     57  0.051913
# 3              ZF17     49  0.044627
# 4              ZF26     36  0.032787
# 5                BF     35  0.031876
# 6          unburned     34  0.030965
# 7  Porcupine (PE04)     33  0.030055
# 8         unburned2     32  0.029144
# 9              ZF14     31  0.028233

# %%
data_burned.groupby(by=['burn_year', 'treatment']).burn_name.count().to_frame()
# Out:
#                      burn_name
# burn_year treatment
# 1966      Control            4
# 1967      Control            2
# 1969      Control            1
#           burn               1
# 1971      burn               6
# 1972      burn               9
# 1980      burn               1
# 1983      burn               1
# 1987      burn               4
# 1990      burn               9
# 1991      burn               1
# 1993      burn               3
# 1994      burn              12
# 1996      burn               4
# 1998      burn               1
# 1999      burn               8
# 2002      burn               2
# 2003      burn              27
# 2004      burn             220
# 2005      burn              17
# 2008      burn               5
# 2010      burn              25
# 2011      burn               1
# 2013      burn               4
# 2014      burn             428
# 2015      burn             123
# 2016      burn              26
# Control   Control           40
# unburned  Control          113

# %%
#replace NA values
data_burned=data_burned.replace(-9999, None)

# %%
data_burned.drought_code.value_counts()
# Out:
# 50.90     28
# 318.80    28
# 263.10    24
# 234.96    23
# 306.50    22
#           ..
# 314.98     1
# 21.90      1
# 196.02     1
# 298.04     1
# 305.98     1
# Name: drought_code, Length: 200, dtype: int64

# %%
data_burned.columns
# Out:
# Index(['project_id', 'project_name', 'treatment', 'site', 'burn_name',
#        'burn_year', 'ecoregion_name_l2', 'latitude', 'longitude',
#        'accuracy_horizontal', 'elevation', 'accuracy_vertical', 'slope',
#        'aspect', 'moisture', 'stand_density', 'stand_basal_area',
#        'prop_black_spruce', 'stand_age', 'stand_origin', 'ag_biomass_prefire',
#        'ag_c_prefire', 'ag_biomass_combusted', 'ag_c_combusted', 'prefire_sol',
#        'mean_residual_org_layer_depth', 'burn_depth', 'prop_sol_combusted',
#        'residual_sol_c', 'bg_c_prefire', 'bg_c_combusted',
#        'prop_sol_c_combusted', 'total_c_pool_prefire', 'prop_prefire_bg_c',
#        'total_c_combusted', 'prop_total_bg_c_combusted',
#        'prop_total_prefire_c_combusted', 'dob', 'precipitation', 'temperature',
#        'relative_humidity', 'wind_speed', 'drought_code',
#        'drought_moisture_code', 'fine_fuel_moisture_code',
#        'initial_spread_index', 'buildup_index', 'fire_weather_index',
#        'daily_severity_rank'],
#       dtype='object')

# %%
#fill NA values with mean
list_cols=['burn_depth','precipitation', 'temperature', 'relative_humidity', 'wind_speed']

for col in list_cols:
    data_burned[col]=data_burned[col].fillna(data_burned[col].mean())

# %%
#Save file
data_burned.to_csv('.\ABoVE\data_burned.csv')

# %%
data_burned.isnull().sum()
# Out:
# project_id                           0
# project_name                         0
# treatment                            0
# site                                 0
# burn_name                           74
# burn_year                            0
# ecoregion_name_l2                    1
# latitude                             0
# longitude                            0
# accuracy_horizontal               1062
# elevation                          497
# accuracy_vertical                 1134
# slope                              539
# aspect                             853
# moisture                           271
# stand_density                      383
# stand_basal_area                   315
# prop_black_spruce                  422
# stand_age                          547
# stand_origin                         0
# ag_biomass_prefire                 518
# ag_c_prefire                       517
# ag_biomass_combusted               557
# ag_c_combusted                     557
# prefire_sol                        298
# mean_residual_org_layer_depth      127
# burn_depth                           0
# prop_sol_combusted                 298
# residual_sol_c                     481
# bg_c_prefire                       442
# bg_c_combusted                     275
# prop_sol_c_combusted               481
# total_c_pool_prefire               593
# prop_prefire_bg_c                  593
# total_c_combusted                  624
# prop_total_bg_c_combusted          624
# prop_total_prefire_c_combusted     625
# dob                                239
# precipitation                        0
# temperature                          0
# relative_humidity                    0
# wind_speed                           0
# drought_code                       252
# drought_moisture_code              252
# fine_fuel_moisture_code            252
# initial_spread_index               252
# buildup_index                      252
# fire_weather_index                 252
# daily_severity_rank                252
# dtype: int64

# %%
target=pd.get_dummies(data_burned['treatment'])
data_burned=pd.concat([data_burned,target])

# %%
data_burned.corr()
# Out:
#                    latitude  longitude  burn_depth  precipitation  \
# latitude           1.000000  -0.763315    0.329444      -0.041766
# longitude         -0.763315   1.000000   -0.419786       0.054592
# burn_depth         0.329444  -0.419786    1.000000       0.016145
# precipitation     -0.041766   0.054592    0.016145       1.000000
# temperature       -0.257279   0.321573   -0.110060       0.041894
# relative_humidity  0.387853  -0.619183    0.409353       0.189760
# wind_speed         0.148102   0.071136    0.002814      -0.070884
# Control                 NaN        NaN         NaN            NaN
# burn                    NaN        NaN         NaN            NaN
#
#                    temperature  relative_humidity  wind_speed  Control  burn
# latitude             -0.257279           0.387853    0.148102      NaN   NaN
# longitude             0.321573          -0.619183    0.071136      NaN   NaN
# burn_depth           -0.110060           0.409353    0.002814      NaN   NaN
# precipitation         0.041894           0.189760   -0.070884      NaN   NaN
# temperature           1.000000          -0.385567   -0.235513      NaN   NaN
# relative_humidity    -0.385567           1.000000    0.027826      NaN   NaN
# wind_speed           -0.235513           0.027826    1.000000      NaN   NaN
# Control                    NaN                NaN         NaN      1.0  -1.0
# burn                       NaN                NaN         NaN     -1.0   1.0
